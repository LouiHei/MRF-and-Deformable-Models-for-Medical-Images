# %% [markdown]
# # Markov random field modelling
#
# Write a function that, given an input image $D$ and a segmentation, for example $S_{GT} = \{1, 2,3\}$ , produces a histogram of the pixel intensities and histograms of the pixel
# intensities divided into segmentation classes.

# %%
import numpy as np
import math
import maxflow
import skimage
import scipy.ndimage as snd
from matplotlib import pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline
import os
#os.chdir("/home/wrenchking/Desktop/Image_Anal_Git/MRF-and-Deformable-Models-for-Medical-Images/data")

# %%
D = skimage.io.imread("noisy_circles.png").astype(np.int);
S = [1, 2, 3]

def Hist(D, S):
    D = 1

f, ax = plt.subplots(1,2, figsize=(10,4))
ax[0].imshow(D, cmap='gray');
ax[1].hist(D.ravel(), bins=60, range=[0,256], rwidth=0.8, color='k');

# %% [markdown]
# What does this histogram say about the chances of obtaining
# a reasonable segmentation of D using a method which considers only
# pixel intensities, for example thresholding?
#
#
# The one clique potentials for the likelihood energy as the squared distance from the
# class mean
#
# $$
# V_{1}\left(f_{i}\right)=\alpha\left(\mu\left(f_{i}\right)-d_{i}\right)^{2}
#  $$
#
#
# ## 5.2 Exercise : Modelling
#
# In this exercise we define an objective function for segmenting a noisy image, similar to the problem in Li Section 3.2.2. \\
#
# We want to be minimizing the posterior energy of the configuration $f$. Our objective function is therefore:
#
# \begin{align}
# min\{ E(f) \} = min\{ U(f|d) \}= min\{ U(d|f)+U(f) \}
# \end{align}
# with the likelihood energy
# \begin{align}
# U(d|f) = \sum_{i \in D}  \alpha \cdot ( \mu ( f_i ) − d_i )^2
# \end{align}
# and the prior energy
# \begin{align}
# U(f) = \sum_{i,j \in D, i \neq j}
# \begin{cases}
# 0 \hspace{5mm} f_i = f_j \\
# 1 \hspace{5mm} \text{otherwise}
# \end{cases}
# \end{align}

# %%
# Define a function to produce histograms:
def Histogrammify(im, imlabeled, whatLabel):
    # Identify indices of the labeled image with specified label. These indices correspond to the original image.
    ilabel = np.asarray(np.where(imlabeled == whatLabel)).T
    temp = list()
    for j in ilabel:
        # Save image pixel values from specified label as a list:
        temp.append(im[tuple(j)])
    temp.sort()
    
    # Sort this list so that no values are repeated. Make a counter to keep track of the amount of repititions:
    PixVals = [temp[0]]
    Counts = [1]
    for j in range(1,len(temp)):
        if temp[j] != temp[j-1]:
            PixVals.append(temp[j]) 
            Counts.append(1)
        else: 
            Counts[-1] +=1
    Counts = np.array(Counts)
    return PixVals, Counts

# Define a function to calculate the image energy (only developed for three labels):
def Energy(im, imlabeled):
    # Define parameters:
    mu = [70, 130, 190]
    alpha = 0.0005
    h,w = im.shape
    LiklhdEnergy = 0
    PriorEnergy = 0

    for r in range(1,h-1):
        for c in range(1,w-1):
            # Start with the Likelihood Energy:
            LiklhdEnergy += alpha*(mu[imlabeled[r,c]-1] - im[r,c])**2  
            
            # alpha*(mu[1] - D)*(mu[1] - D) also works, but passing imlabel as indices to mu is hard:
            # list2label = np.asarray(np.where(Dlabel == 1)).T.tolist() 
            # print(list2label)
            # for i in list2label:
                # print(D[tuple(i)]) so you would also need two for-loops...
            
            # Now look at the prior energy: take the four neighbours and compare labels
            CompList = np.asarray([imlabeled[r-1,c], imlabeled[r+1,c], imlabeled[r,c-1], imlabeled[r,c+1]])
            trues = (CompList != imlabeled[r,c])
            PriorEnergy += sum(trues)
            
    return round(LiklhdEnergy,2), PriorEnergy

def Energy2(im,imLabeled):
    mu=np.unique(imLabeled)
    alpha=0.0005
    y,x=im.shape
    liklhoodEnergy=0
    priorEnergy=0
    for i in range(1,y-1):
        for j in range(1,x-1):
            liklhoodEnergy+=alpha*mu

# %% [markdown]
# ### 5.2.1 The ground truth
#
# A linear mapping can be used to obtain a desired minimum pixel value $v_{min,d}$ and maximum $v_{max,d}$
#
# \begin{align}
# g(x,y) = \frac{v_{max,d} - v_{min,d}}{v_{max} - v_{min}} \cdot (f(x,y) - v_{min}) + v_{min,d}
# \end{align}

# %% [markdown]
# A linear mapping can be used to obtain a desired minimum pixel value $v_{min,d}$ and maximum $v_{max,d}$
#
# \begin{align}
# g(x,y) = \frac{v_{max,d} - v_{min,d}}{v_{max} - v_{min}} \cdot (f(x,y) - v_{min}) + v_{min,d}
# \end{align}

# %%
GT = skimage.io.imread("noise_free_circles.png").astype(np.int);

# What are the maximum and minimum values in D?
print('The three different values in GT are', (GT[10,90], GT[30,70], GT[1,1]))

# We want to rescale (70, 130, 190) to (1,2,3):
GTlabel = (3-1)/(190-70)*(GT-70) + 1
GTlabel = GTlabel.astype(np.int)
print('The three different labels in GT are', (GTlabel[10,90], GTlabel[30,70], GTlabel[1,1]),'\n')

f, ax = plt.subplots(1,2, figsize=(8,3))
[axi.set_axis_off() for axi in ax.ravel()]
ax[0].imshow(GT, cmap='gray')
ax[0].set(title=('Original ground truth GT'))
ax[1].imshow(GTlabel);
ax[1].set(title=('Fully labeled map (1,2,3)'))

energy = Energy(GT, GTlabel)
print('For the ground truth, the likelihood energy is', energy[0], 'and the prior energy is',energy[1])
print('The total energy is', energy[0] + energy[1])
# Out:
# The three different values in GT are (70, 130, 190)
# The three different labels in GT are (1, 2, 3)
#
# For the ground truth, the likelihood energy is 0.0 and the prior energy is 1268
# The total energy is 1268.0

# %%
# Histogram of the ground truth
plt.hist(GT.ravel(), bins=60, range=[0,256], rwidth=0.8, color='k');
for i in (1,2,3):
    PixVals, Counts = Histogrammify(GT, GTlabel, i)
    plt.scatter(PixVals, Counts, s = 50  )

# %% [markdown]
# ### 5.2.2 Segmentation based on simple thresholding

# %%
D = skimage.io.imread("noisy_circles.png").astype(np.int);

# Threshold D in D1, D2 and D3 with corresponding labels 1,2 and 3: (black = false, white = true)
D1 = (D < 100)*1
D2 = np.logical_and(D >= 100, D < 160)*2
D3 = (D >= 160)*3

# Make a 'complete' label map for D:
Dlabel = D1 + D2 + D3

# With this segmentation, already a clear distinction between background, and foreground is visible
f, ax = plt.subplots(1,5, figsize=(20,4))
[axi.set_axis_off() for axi in ax.ravel()]
ax[0].imshow(D, cmap='gray')
ax[0].set(title=('Original noisy image D'))
ax[1].imshow(D1, cmap='gray');
ax[1].set(title=('Label (1): D < 100'))
ax[2].imshow(D2, cmap='gray');
ax[2].set(title=(r'Label (2): 100 $\leq$ D < 160'))
ax[3].imshow(D3, cmap='gray');
ax[3].set(title=(r'Label (3): D $\geq$ 160'));
ax[4].imshow(Dlabel);
ax[4].set(title=('Fully labeled map (1,2,3)'));

energy = Energy(D, Dlabel)
print('For the segmentation based on thresholding, the likelihood energy is', energy[0], 'and the prior energy is',energy[1])
print('The total energy is', energy[0] + energy[1])
print('This is a lot higher than the ground truth.')
# Out:
# For the segmentation based on thresholding, the likelihood energy is 1453.47 and the prior energy is 7052
# The total energy is 8505.47
# This is a lot higher than the ground truth.

# %%
# Intermediate work: histogram of the thresholded image
plt.hist(D.ravel(), bins=256, range=[0,256], color='k');
for i in (1,2,3):
    PixVals, Counts = Histogrammify(D, Dlabel, i)
    plt.plot(PixVals, Counts)

# %% [markdown]
# ### 5.2.3 Segmentation based on median filtering

# %%
D1Median = skimage.filters.median(D1)
D2Median = skimage.filters.median(D2)
D3Median = skimage.filters.median(D3)

DMedianLabel = D1Median + D2Median + D3Median

# With this segmentation, already a clear distinction between background, and foreground is visible
f, ax = plt.subplots(1,5, figsize=(20,4))
[axi.set_axis_off() for axi in ax.ravel()]
ax[0].imshow(D, cmap='gray')
ax[0].set(title=('Original noisy image D'))
ax[1].imshow(D1Median, cmap='gray');
ax[1].set(title=('Label (1): D < 100'))
ax[2].imshow(D2Median, cmap='gray');
ax[2].set(title=(r'Label (2): 100 $\leq$ D < 160'))
ax[3].imshow(D3Median, cmap='gray');
ax[3].set(title=(r'Label (3): D $\geq$ 160'));
ax[4].imshow(DMedianLabel);
ax[4].set(title=('Fully labeled map (1,2,3)'));

energy = Energy(D, DMedianLabel)
print('For the segmentation based on thresholding, the likelihood energy is', energy[0], 'and the prior energy is',energy[1])
print('The total energy is', energy[0] + energy[1])
print('This is a lot lower than the simple thresholding: we can see that pixels are more "distant" from their mean (LE is higher) but neighbours are labeled very well.')


print(np.unique(D1Median))
print(np.unique(D2Median))
print(np.unique(D3Median))
print(np.unique(DMedianLabel))
# Out:
# /home/louis/env/py36cv4/lib/python3.6/site-packages/skimage/util/dtype.py:137: UserWarning: Possible sign loss when converting negative image of type int64 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/louis/env/py36cv4/lib/python3.6/site-packages/skimage/util/dtype.py:190: UserWarning: Downcasting int64 to uint8 without scaling because max value 1 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/louis/env/py36cv4/lib/python3.6/site-packages/skimage/util/dtype.py:190: UserWarning: Downcasting int64 to uint8 without scaling because max value 2 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/louis/env/py36cv4/lib/python3.6/site-packages/skimage/util/dtype.py:190: UserWarning: Downcasting int64 to uint8 without scaling because max value 3 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# For the segmentation based on thresholding, the likelihood energy is 2220.81 and the prior energy is 1534
# The total energy is 3754.81
# This is a lot lower than the simple thresholding: we can see that pixels are more "distant" from their mean (LE is higher) but neighbours are labeled very well.
# [0 1]
# [0 2]
# [0 3]
# [0 1 2 3 5]

# %%
plt.hist(D.ravel(), bins=256, range=[1,256], color='k');
for i in (1,2,3):
    PixVals, Counts = Histogrammify(D, DMedianLabel, i)
    plt.plot(PixVals, Counts)

# %% [markdown]
# ## 5.3 Exercise: Iterative Optimization for MRF

# %%
def oneClique(mean,points):
    return np.sum((points-mean)**2)

def twoClique(points):
    y,x=points.shape
    counting=np.zeros((y,x))
    for i in range(-1,2):
        for j in range(-1,2):
            tmp = points[1:y-1,1:x-1] > points[1+j:y-1+j,1+i:x-1+i]
            counting[1:y-1,1:x-1] += tmp.astype(float)
    return np.sum(counting)/2


def icm (segmentation,img,alpha):
    y,x=img.shape
    mu=np.unique(segmentation)
    diffDict=dict()
    
#     
    for k in mu:
        diffNeighborCt=np.zeros((y,x))
        for i,h in [(0,1),(1,0),(-1,0),(0,-1)]:
            tmp = img[1+i:y-1+i,1+h:x-1+h]!=k
            diffNeighborCt[1:y-1,1:x-1] += tmp
        diffDict[k]=diffNeighborCt
    vVals=np.zeros((y,x))
    for i in range(y):
        for j in range(x):
            temp=[]
            for k in mu:
                temp.append(alpha*(k-img[i,j])**2+diffDict[k][i,j])
            #temp.append(alpha*(segmentation[i,j]-img[i,j])**2+diffNeighborCt[i,j])
            vVals[i][j]=mu[temp.index(min(temp))]
    return vVals    

def icm2 (segmentation,img,alpha):
    y,x=img.shape
    mu=np.unique(segmentation)
    print(mu)
    diffDict=dict()
    vVals=np.zeros((y,x))
   
    temp=[] 
    for k in mu:


        diffNeighborCt=np.zeros((y,x))
        for i,h in [(0,1),(1,0),(-1,0),(0,-1)]:
            tmp = img[1:y-1,1:x-1] != img[1+i:y-1+i,1+h:x-1+h]
            print("tmp "+str(tmp.shape))
           # tmp = img[1+i:y-2+i,1+h:x-2+h]!=k
            diffNeighborCt[1:y-1,1:x-1] += tmp
            print("diff "+str(diffNeighborCt.shape))
        temp.append(alpha*(k-img)**2+diffNeighborCt)
    print("temp "+str(len(temp)))
    print("temp 0 "+str(temp[0]))
      #  diffDict[k]=diffNeighborCt
    comp=[np.sum(x) for x in temp]
    vVals=temp[comp.index(min(comp))]
    return vVals

# %%
blur=skimage.io.imread("noisy_circles.png").astype(np.int);
seg=skimage.io.imread("noise_free_circles.png").astype(np.int);

alpha=0.0000001
out=icm(seg,blur,alpha)
out2=icm(seg,out,alpha)
out3=icm(seg,out2,alpha)
out4=icm(seg,out3,alpha)
out5=icm(seg,out4,alpha)
out6=icm(seg,out5,alpha)
out7=icm(seg,out6,alpha)
out8=icm(seg,out7,alpha)
out9=icm(seg,out8,alpha)

print(np.min(out),np.max(out))
print(np.min(out2),np.max(out2))
print(np.min(out3),np.max(out3))
print(np.min(out4),np.max(out4))
print(np.min(out5),np.max(out5))
# Out:
# 70.0 190.0
# 70.0 190.0
# 70.0 190.0
# 70.0 190.0
# 70.0 190.0

# %%
e=Energy(out9,GTlabel)
print(e)
# Out:
# (333.0, 1268)

# %%
fig,ax=plt.subplots(6,2,figsize=(40,40))
ax[0][0].imshow(seg)
ax[0][0].set_title("seg")

ax[0][1].imshow(blur)
ax[0][1].set_title("blur")

ax[1][0].imshow(out)
ax[1][0].set_title("out")

ax[1][1].imshow(out2)
ax[1][1].set_title("out2")
ax[2][0].imshow(out3)
ax[2][0].set_title("out3")
ax[2][1].imshow(out4)
ax[2][1].set_title("out4")

ax[3][0].imshow(out5)
ax[3][0].set_title("out5")
ax[3][1].imshow(out6)
ax[3][1].set_title("out6")


ax[4][0].imshow(out7)
ax[4][0].set_title("out7")
ax[4][1].imshow(out8)
ax[4][1].set_title("out8")

ax[5][0].imshow(out9)
ax[5][0].set_title("out9")
# Out:
# Text(0.5, 1.0, 'out9')

# %%
from maxflow.fastmin import aexpansion_grid
import imageio

Ifuck = imageio.imread("V12_10X_x502.png")
plt.imshow(Ifuck)
I = Ifuck[:,:]/Ifuck.max()

# Generates 16 gray levels for nearsest prototype labeling
L = 4
levs = np.arange(0.5/L, 1, 1/L)

# Calculate data cost as the absolute difference between the label prototype and the pixel value
D = np.abs(I.reshape(I.shape+(1,)) - levs.reshape((1,1,-1)))

# Generate nearest prototype labeling
Id = np.argmin(D,2)

# Calculate neighbourhood cost as absolute difference between prototypes 
alpha = 0
V = alpha * np.abs( levs.reshape((-1,1)) - levs.reshape((1,-1)))

# Mimimise data + neighbourhood cost
labels = aexpansion_grid(D,V)

f, ax = plt.subplots(figsize=(15,8), ncols=2)
titles = ['Direct labeling', 'Regularised labeling']
ax[0].imshow(Id)
ax[1].imshow(labels)

for i in range(len(titles)):
    ax[i].set(title=titles[i])

# %%
Ifuck = skimage.io.imread("V12_10X_x502.png").astype(np.int)
Ifuck = Ifuck/np.max(Ifuck)
plt.hist(labels.ravel(),bins=100);

# %% [markdown]
# ## 5.5 Exercise: Binary image segmentation
#
# Next, we'll explore how to use the maxflow library to segment a CT scan of a mouse tibia.
# The first step consists of loading the image and scaling down its values from uint16 range $(2^{16} = 65535)$ to floating numbers between 0.0 and 1.0.

# %%
# cd data/

# %%
# read file & convert to double precision float
boneCT = 'V12_10X_x502.png'
img = skimage.io.imread(boneCT).astype(np.float64)
img = img/65535 # original image has uint16 (range 0 to 65535)

f, ax = plt.subplots(1,2, figsize=(17,4))
ax[0].imshow(img, cmap='gray');
ax[0].set(title='Original image', xticks=[], yticks=[])
ax[1].hist(img.ravel(), bins=60, range=[0,1], color='k');
ax[1].set(title='Image Histogram');

# %% [markdown]
# Next, graph cuts are calculated with different edge capacities. The goal is to separate bone structure from air and cartilage.
#
# A reasonable segmentation is obtained for edge capacities around 0.4 - 0.6:

# %%
import scipy
import maxflow

# Create the graph.
g = maxflow.Graph[float]()

# make each pixel of the image a (consecutively labeled) node
nodes = g.add_grid_nodes(img.shape)



f, ax = plt.subplots(figsize = (17,15), nrows=3, ncols=2)

for index, i in enumerate(range(4,7)):
    
    # Add non-terminal edges with the same capacity as the nodes
    g.add_grid_edges(nodes, i/10)
    # Add the terminal edges. The image pixels are the capacities
    # of the edges from the source node. The inverted image pixels
    # are the capacities of the edges to the sink node.
    g.add_grid_tedges(nodes, img, 1.0-img)

    # Compute maximum flow.
    g.maxflow()
    
    # Get the segments of the nodes in the grid.
    # Their labels are 1 where sgm is False and 0 otherwise.
    sgm = g.get_grid_segments(nodes)

    ax[index][0].imshow(np.int_(np.logical_not(sgm)));
    ax[index][0].set(title=('Edge capacities between nodes: '+ str(i/10)), 
                            xticks=[], yticks=[])
    ax[index][1].imshow(img, cmap='gray');
    ax[index][1].set(title='Original image', xticks=[], yticks=[])
