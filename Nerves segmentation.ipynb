# %% [markdown]
# # Assignment on geometric priors
# This code contains the answers to the Nerves segmentation
# Group members:
# - Simon Aertssen s181603
# - Louis Hein s181573
# - Andrew Chase Ardueser s182332

# %%
import numpy as np
import math
import skimage
import scipy.ndimage as snd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from PIL import Image
#im = Image.open('nerves_part.tiff')
im = skimage.io.imread('nerves_part.tiff')
#plt.imshow(im)
print(im.shape)
plt.imshow(im[-1,:,:])
# Out:
# (1024, 350, 350)
